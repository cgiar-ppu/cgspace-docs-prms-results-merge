# %% [markdown]
# This code will merge the data (metadata/attachments) from CGSpace with the PRMS results. At the end, we will have an output file containing all the PRMS results along with the text of the evidences attached with each results.
#
# The evidence links mostly correspond to CGSpace Items, while some refer to Sharepoint articles. We will only consider the evidences from two sources (CGSpace, Sharepoint)

# %%
import os
import pandas as pd

# %% [markdown]
# ### Reading the PRMS Results

# %%
prms_results_dir = "prms_results"
prms_results_file = os.path.join(prms_results_dir, "Result_AI.xlsx")
prms_comp_results = pd.read_excel(prms_results_file, sheet_name='fact_results', engine="openpyxl")
prms_evidences = pd.read_excel(prms_results_file, sheet_name='result_main_evidences', engine="openpyxl")

# %%
len(prms_comp_results), len(prms_evidences)
# Out:
# (19425, 28743)

# %% [markdown]
# Filtering out all the `main` evidences having valid links

# %%
prms_evidences = prms_evidences[(prms_evidences['evidence_type']=='main') & (prms_evidences['valid_link'].notna())].reset_index(drop=True)
prms_evidences
# Out:
#           id                                        description  \
# 0          1                                                NaN
# 1      29654                                                NaN
# 2      22477                                                NaN
# 3      22475                                                NaN
# 4      22398                                                NaN
# ...      ...                                                ...
# 14641   4445  Related 2022 Journal Article Publication - Mod...
# 14642  10795  The whole document (2-page brief) is about the...
# 14643  17107  This thesis focuses on understanding everyday ...
# 14644  11946  The aim of the video is to promote healthy eat...
# 14645  16227  The presented slide deck has been published to...
#
#        gender_related                                 link  youth_related  \
# 0                 NaN  https://hdl.handle.net/10568/125437            NaN
# 1                 NaN  https://hdl.handle.net/10568/151784            NaN
# 2                 NaN  https://hdl.handle.net/10568/135090            NaN
# 3                 NaN  https://hdl.handle.net/10568/135209            NaN
# 4                 NaN  https://hdl.handle.net/10568/135271            NaN
# ...               ...                                  ...            ...
# 14641             0.0  https://hdl.handle.net/10568/127913            0.0
# 14642             0.0  https://hdl.handle.net/10568/137383            0.0
# 14643             0.0  https://hdl.handle.net/10568/131816            0.0
# 14644             0.0  https://hdl.handle.net/10568/131464            0.0
# 14645             0.0  https://hdl.handle.net/10568/135096            0.0
#
#        is_supplementary  result_id  knowledge_product_related  Index  \
# 0                   0.0          4                        NaN      1
# 1                   0.0      13282                        NaN      1
# 2                   0.0      13337                        NaN      1
# 3                   0.0      13335                        NaN      1
# 4                   0.0      13314                        NaN      1
# ...                 ...        ...                        ...    ...
# 14641               0.0        874                     3294.0      1
# 14642               0.0       7724                     7695.0      1
# 14643               0.0       6982                     7033.0      1
# 14644               0.0       7180                     6643.0      1
# 14645               0.0       6961                     6961.0      1
#
#        is_valid_link evidence_type                           valid_link
# 0                  1          main  https://hdl.handle.net/10568/125437
# 1                  1          main  https://hdl.handle.net/10568/151784
# 2                  1          main  https://hdl.handle.net/10568/135090
# 3                  1          main  https://hdl.handle.net/10568/135209
# 4                  1          main  https://hdl.handle.net/10568/135271
# ...              ...           ...                                  ...
# 14641              1          main  https://hdl.handle.net/10568/127913
# 14642              1          main  https://hdl.handle.net/10568/137383
# 14643              1          main  https://hdl.handle.net/10568/131816
# 14644              1          main  https://hdl.handle.net/10568/131464
# 14645              1          main  https://hdl.handle.net/10568/135096
#
# [14646 rows x 12 columns]

# %% [markdown]
# Mapping the complete results with their respective evidence. One result ID can have multiple evidences.
#
# Inner join is applied so that we can get only those results for which we have `main` evidence and `valid links` available

# %%
prms_results = pd.merge(prms_comp_results, prms_evidences, how='inner', on='result_id', suffixes=('_comp', '_evidences')).reset_index(drop=True)
prms_results
# Out:
#                                         description_comp  is_active  \
# 0                                                    NaN          1
# 1                                                    NaN          1
# 2                                                    NaN          1
# 3                                                    NaN          1
# 4                                                    NaN          1
# ...                                                  ...        ...
# 14335  Global food, fuel, and fertilizer prices have ...          1
# 14336  Global food, fuel, and fertilizer prices have ...          1
# 14337  Global food, fuel, and fertilizer prices have ...          1
# 14338  The strengthening and scaling-up of Local Tech...          1
# 14339  The strengthening and scaling-up of Local Tech...          1
#
#        gender_tag_level_id  version_id  status  \
# 0                      NaN           3       0
# 1                      2.0           4       1
# 2                      1.0           4       1
# 3                      NaN           3       0
# 4                      NaN           3       0
# ...                    ...         ...     ...
# 14335                  1.0           1       1
# 14336                  1.0           1       1
# 14337                  1.0           1       1
# 14338                  1.0           1       1
# 14339                  1.0           1       1
#
#                                                    title legacy_id  \
# 0      Standard Operating Procedure for Farmer Segmen...       NaN
# 1      State level stakeholder consultation on partic...       NaN
# 2      State level stakeholder consultation on partic...       NaN
# 3      Landscape-specific fertilizer advisory scaling...       NaN
# 4      Current innovations in making site specific nu...       NaN
# ...                                                  ...       ...
# 14335  Policy responses to the impacts of the Ukraine...       NaN
# 14336  Policy responses to the impacts of the Ukraine...       NaN
# 14337  Policy responses to the impacts of the Ukraine...       NaN
# 14338  Implementation of climate services at national...       NaN
# 14339  Implementation of climate services at national...       NaN
#
#                                                  krs_url  is_krs  \
# 0                                                    NaN     NaN
# 1                                                    NaN     1.0
# 2                                                    NaN     1.0
# 3                                                    NaN     NaN
# 4                                                    NaN     NaN
# ...                                                  ...     ...
# 14335  https://www.cgiar.org/initiative-result/the-co...     1.0
# 14336  https://www.cgiar.org/initiative-result/the-co...     1.0
# 14337  https://www.cgiar.org/initiative-result/the-co...     1.0
# 14338  https://www.cgiar.org/initiative-result/implem...     1.0
# 14339  https://www.cgiar.org/initiative-result/implem...     1.0
#
#        climate_change_score  ...  \
# 0                       NaN  ...
# 1                       2.0  ...
# 2                       1.0  ...
# 3                       NaN  ...
# 4                       NaN  ...
# ...                     ...  ...
# 14335                   1.0  ...
# 14336                   1.0  ...
# 14337                   1.0  ...
# 14338                   3.0  ...
# 14339                   3.0  ...
#
#                                    description_evidences  gender_related  \
# 0                                                    NaN             NaN
# 1                                                    NaN             NaN
# 2                                                    NaN             NaN
# 3                                                    NaN             NaN
# 4                                                    NaN             NaN
# ...                                                  ...             ...
# 14335  https://hdl.handle.net/10568/127728_x000D_\nht...             NaN
# 14336                https://hdl.handle.net/10568/127824             NaN
# 14337  https://hdl.handle.net/10568/125312_x000D_\nht...             NaN
# 14338                                                NaN             NaN
# 14339                         Entire document, see p. 14             0.0
#
#                                       link  youth_related is_supplementary  \
# 0      https://hdl.handle.net/10568/137962            NaN              0.0
# 1      https://hdl.handle.net/10568/173161            NaN              0.0
# 2      https://hdl.handle.net/10568/173159            NaN              0.0
# 3      https://hdl.handle.net/10568/139478            NaN              0.0
# 4      https://hdl.handle.net/10568/130359            NaN              0.0
# ...                                    ...            ...              ...
# 14335  https://hdl.handle.net/10568/127730            NaN              0.0
# 14336  https://hdl.handle.net/10568/127611            NaN              0.0
# 14337  https://hdl.handle.net/10568/125314            NaN              0.0
# 14338  https://hdl.handle.net/10568/126467            NaN              0.0
# 14339  https://hdl.handle.net/10568/126473            1.0              0.0
#
#       knowledge_product_related  Index is_valid_link  evidence_type  \
# 0                           NaN      1             1           main
# 1                           NaN      1             1           main
# 2                           NaN      1             1           main
# 3                           NaN      1             1           main
# 4                           NaN      1             1           main
# ...                         ...    ...           ...            ...
# 14335                    3297.0      3             1           main
# 14336                    2222.0      2             1           main
# 14337                     500.0      1             1           main
# 14338                       NaN      2             1           main
# 14339                    1612.0      1             1           main
#
#                                 valid_link
# 0      https://hdl.handle.net/10568/137962
# 1      https://hdl.handle.net/10568/173161
# 2      https://hdl.handle.net/10568/173159
# 3      https://hdl.handle.net/10568/139478
# 4      https://hdl.handle.net/10568/130359
# ...                                    ...
# 14335  https://hdl.handle.net/10568/127730
# 14336  https://hdl.handle.net/10568/127611
# 14337  https://hdl.handle.net/10568/125314
# 14338  https://hdl.handle.net/10568/126467
# 14339  https://hdl.handle.net/10568/126473
#
# [14340 rows x 62 columns]

# %% [markdown]
# ### Reading the CGSpace Results

# %%
cgspace_data_dir = "cgspace_data"
cgspace_data_list = os.listdir(cgspace_data_dir)
cgspace_comp_data = pd.DataFrame()
for file in cgspace_data_list:
    if file.endswith(".xlsx"):
        cgspace_results_file = os.path.join(cgspace_data_dir, file)
        df_temp = pd.read_excel(cgspace_results_file, engine="openpyxl")
        cgspace_comp_data = pd.concat([cgspace_comp_data, df_temp], ignore_index=True)

# %% [markdown]
# Applying the left join on `prms_results` with `cgspace_comp_data` on item handles. Left join is used because all the links in the PRMS are NOT CGSPACE handle links, some are SharePoint links and should be considered

# %%
prms_final_data = pd.merge(prms_results, cgspace_comp_data, how='left', left_on='valid_link', right_on='dc.identifier.uri', suffixes=('_prms', '_cgspace'))

# %%
len(prms_final_data)
# Out:
# 24254

# %%
prms_final_data
# Out:
#                                         description_comp  is_active  \
# 0                                                    NaN          1
# 1                                                    NaN          1
# 2                                                    NaN          1
# 3                                                    NaN          1
# 4                                                    NaN          1
# ...                                                  ...        ...
# 24249  The strengthening and scaling-up of Local Tech...          1
# 24250  The strengthening and scaling-up of Local Tech...          1
# 24251  The strengthening and scaling-up of Local Tech...          1
# 24252  The strengthening and scaling-up of Local Tech...          1
# 24253  The strengthening and scaling-up of Local Tech...          1
#
#        gender_tag_level_id  version_id  status  \
# 0                      NaN           3       0
# 1                      2.0           4       1
# 2                      1.0           4       1
# 3                      1.0           4       1
# 4                      NaN           3       0
# ...                    ...         ...     ...
# 24249                  1.0           1       1
# 24250                  1.0           1       1
# 24251                  1.0           1       1
# 24252                  1.0           1       1
# 24253                  1.0           1       1
#
#                                                    title legacy_id  \
# 0      Standard Operating Procedure for Farmer Segmen...       NaN
# 1      State level stakeholder consultation on partic...       NaN
# 2      State level stakeholder consultation on partic...       NaN
# 3      State level stakeholder consultation on partic...       NaN
# 4      Landscape-specific fertilizer advisory scaling...       NaN
# ...                                                  ...       ...
# 24249  Implementation of climate services at national...       NaN
# 24250  Implementation of climate services at national...       NaN
# 24251  Implementation of climate services at national...       NaN
# 24252  Implementation of climate services at national...       NaN
# 24253  Implementation of climate services at national...       NaN
#
#                                                  krs_url  is_krs  \
# 0                                                    NaN     NaN
# 1                                                    NaN     1.0
# 2                                                    NaN     1.0
# 3                                                    NaN     1.0
# 4                                                    NaN     NaN
# ...                                                  ...     ...
# 24249  https://www.cgiar.org/initiative-result/implem...     1.0
# 24250  https://www.cgiar.org/initiative-result/implem...     1.0
# 24251  https://www.cgiar.org/initiative-result/implem...     1.0
# 24252  https://www.cgiar.org/initiative-result/implem...     1.0
# 24253  https://www.cgiar.org/initiative-result/implem...     1.0
#
#        climate_change_score  ...  cg.subject.humidtropics  \
# 0                       NaN  ...                      NaN
# 1                       2.0  ...                      NaN
# 2                       1.0  ...                      NaN
# 3                       1.0  ...                      NaN
# 4                       NaN  ...                      NaN
# ...                     ...  ...                      ...
# 24249                   3.0  ...                      NaN
# 24250                   3.0  ...                      NaN
# 24251                   3.0  ...                      NaN
# 24252                   3.0  ...                      NaN
# 24253                   3.0  ...                      NaN
#
#        cg.subject.drylands  cg.subject.icarda  dc.description.abstract  \
# 0                      NaN                NaN                      NaN
# 1                      NaN                NaN                      NaN
# 2                      NaN                NaN                      NaN
# 3                      NaN                NaN                      NaN
# 4                      NaN                NaN                      NaN
# ...                    ...                ...                      ...
# 24249                  NaN                NaN                      NaN
# 24250                  NaN                NaN                      NaN
# 24251                  NaN                NaN                      NaN
# 24252                  NaN                NaN                      NaN
# 24253                  NaN                NaN                      NaN
#
#       dcterms.isVersionOf dcterms.references  dc.contributor.advisor  \
# 0                     NaN                NaN                     NaN
# 1                     NaN                NaN                     NaN
# 2                     NaN                NaN                     NaN
# 3                     NaN                NaN                     NaN
# 4                     NaN                NaN                     NaN
# ...                   ...                ...                     ...
# 24249                 NaN                NaN                     NaN
# 24250                 NaN                NaN                     NaN
# 24251                 NaN                NaN                     NaN
# 24252                 NaN                NaN                     NaN
# 24253                 NaN                NaN                     NaN
#
#       dc.contributor.other  dcterms.isFormatOf dcterms.isReplacedBy
# 0                      NaN                 NaN                  NaN
# 1                      NaN                 NaN                  NaN
# 2                      NaN                 NaN                  NaN
# 3                      NaN                 NaN                  NaN
# 4                      NaN                 NaN                  NaN
# ...                    ...                 ...                  ...
# 24249                  NaN                 NaN                  NaN
# 24250                  NaN                 NaN                  NaN
# 24251                  NaN                 NaN                  NaN
# 24252                  NaN                 NaN                  NaN
# 24253                  NaN                 NaN                  NaN
#
# [24254 rows x 171 columns]

# %% [markdown]
# Storing the combined data of PRMS and CGSpace

# %%
merged_file_dir = "prms_cgspace_merged"
merged_file_name = "prms_cgspace_merged_data.xlsx"
os.makedirs(merged_file_dir, exist_ok=True)
merged_file_path = os.path.join(merged_file_dir, merged_file_name)
prms_final_data.to_excel(merged_file_path, index=False, engine="openpyxl")

# %% [markdown]
# Now analyzing some points from the combined data to verify the data

# %%
prms_final_data['Type'].value_counts()
# Out:
# Type
# Knowledge product                   16445
# Innovation development               4066
# Capacity sharing for development      927
# Other output                          914
# Innovation use                        690
# Policy change                         629
# Other outcome                         567
# Capacity change                        14
# Impact contribution                     2
# Name: count, dtype: int64

# %%
prms_final_data['phase_year'].value_counts()
# Out:
# phase_year
# 2024    12723
# 2023     7668
# 2022     3863
# Name: count, dtype: int64

# %%
prms_final_data['dcterms.issued'].value_counts()
# Out:
# dcterms.issued
# 2024-12       1166
# 2023           988
# 2024           755
# 2024-12-30     740
# 2023-12        547
#               ...
# 2022-01-13       1
# 2023-04-22       1
# 2023-03-11       1
# 2024-12-07       1
# 2022-08-05       1
# Name: count, Length: 1053, dtype: int64

# %%
prms_final_data['dcterms.issued_year'] = prms_final_data['dcterms.issued'].apply(lambda x: str(x).split("-")[0] if pd.notna(x) else x).astype('Int64')

# %%
prms_final_data[(prms_final_data['phase_year'] != prms_final_data['dcterms.issued_year']) & (prms_final_data['dcterms.issued_year'].notna()) & (prms_final_data['dcterms.issued_year']<2020)][['result_id','phase_year','dcterms.issued_year','valid_link','dc.identifier.uri']].drop_duplicates().iloc[:20,:]
# Out:
#       result_id  phase_year  dcterms.issued_year  \
# 4208       5209        2023                 2019
# 4537      13201        2024                 2015
# 4552      12814        2024                 2017
# 4656      12816        2024                 2017
# 4657      12816        2024                 2017
# 4661      12825        2024                 2018
# 4679       4853        2023                 2017
# 4686       4852        2023                 2019
# 4692       4855        2023                 2017
# 4693       4855        2023                 2017
# 4698       4865        2023                 2018
# 4713       6217        2023                 2015
# 5001       2392        2022                 2018
# 5005       2392        2022                 2019
# 5073      20309        2024                 2017
# 5206      18712        2024                 2019
# 5231      10146        2023                 2019
# 5233       7185        2023                 2019
# 5530      21307        2024                 2010
# 5608      19166        2024                 2017
#
#                                valid_link                    dc.identifier.uri
# 4208  https://hdl.handle.net/10568/105482  https://hdl.handle.net/10568/105482
# 4537   https://hdl.handle.net/10568/71211   https://hdl.handle.net/10568/71211
# 4552   https://hdl.handle.net/10568/82813   https://hdl.handle.net/10568/82813
# 4656   https://hdl.handle.net/10568/82984   https://hdl.handle.net/10568/82984
# 4657   https://hdl.handle.net/10568/89800   https://hdl.handle.net/10568/89800
# 4661  https://hdl.handle.net/10568/103725  https://hdl.handle.net/10568/103725
# 4679   https://hdl.handle.net/10568/82813   https://hdl.handle.net/10568/82813
# 4686   https://hdl.handle.net/10568/79426   https://hdl.handle.net/10568/79426
# 4692   https://hdl.handle.net/10568/82984   https://hdl.handle.net/10568/82984
# 4693   https://hdl.handle.net/10568/89800   https://hdl.handle.net/10568/89800
# 4698  https://hdl.handle.net/10568/103725  https://hdl.handle.net/10568/103725
# 4713   https://hdl.handle.net/10568/71211   https://hdl.handle.net/10568/71211
# 5001   https://hdl.handle.net/10568/99262   https://hdl.handle.net/10568/99262
# 5005  https://hdl.handle.net/10568/124548  https://hdl.handle.net/10568/124548
# 5073   https://hdl.handle.net/10568/83054   https://hdl.handle.net/10568/83054
# 5206  https://hdl.handle.net/10568/122939  https://hdl.handle.net/10568/122939
# 5231  https://hdl.handle.net/10568/123337  https://hdl.handle.net/10568/123337
# 5233  https://hdl.handle.net/10568/122939  https://hdl.handle.net/10568/122939
# 5530   https://hdl.handle.net/10568/99430   https://hdl.handle.net/10568/99430
# 5608   https://hdl.handle.net/10568/80548   https://hdl.handle.net/10568/80548
